# %%
import pandas as pd

# %%
df = pd.read_csv('diablo_2__resurrected.csv') ## What's my highest level character in my Diablo 2 logbook.
df.sort_values(by = ['Level'], ascending=False)
# Out:
#          Nickname  Level        Class Character_Created          Entry_Added  \
# 24         Coolio     98    Sorceress        2023-06-01  2024-02-14 00:00:00
# 12   LAPPAHLAPAPP     94      Paladin        2000-01-01  2023-10-05 17:39:58
# 7    LAPPAHLAPAPP     91      Paladin        2000-01-01  2022-12-04 00:00:00
# 9    MULEMULEMULE     87    Barbarian        2000-01-01  2023-10-05 17:39:11
# 11    AMAMMAMOOAH     86       Amazon        2000-01-01  2023-10-05 17:39:58
# 14     CARDANOADA     84    Sorceress        2000-01-01  2023-10-05 17:40:30
# 22   DROODOLOLLEE     83        Druid        2000-01-01  2023-10-05 17:42:00
# 6      CARDANOADA     82    Sorceress        2000-01-01  2022-12-04 00:00:00
# 23        POPULUS     53    Sorceress        2000-01-01  2023-10-05 17:42:10
# 8         POPULUS     53    Sorceress        2000-01-01  2022-12-04 00:00:00
# 3    DROODOLOLLEE     40        Druid        2000-01-01  2022-12-04 00:00:00
# ...

# %%
df2 = pd.read_csv('ultima_online_outlands.csv') # What order did I create my UOO characters?
df2.sort_values(by = ['Character_Created'])
# Out:
#             Nickname                                           Template  \
# 0   Sgt Dinkle Birch                                   Veterinary-tamer
# 5             George            Fencing and Parrying dexer with magery.
# 10         Gabriella                                              Thief
# 6            Twindle                                           Gatherer
# 7         Cartwright                           T-mapper and lockpicker.
# 1               Jean                                           Gatherer
# 3           Barklund                                           Tankmage
# 8            Murdock                Tankmage with alchemy and poisoning
# 12           Populus                                           Tankmage
# 13  a frenzied harpy                                            Crafter
# 14        Jazzy Beat  Hally-stealth-PK with Taming and stealth-spiders.
# 4             Konsum            Peacemaking and Discordance macing-bard
# ...

# %%
df3 = pd.read_csv('pok__mon_go.csv') # How much did I play Pokémon during my last logbook entries?

df3['Distance_Walked_ROC'] = df3['Distance_Walked'].pct_change() * 100
df3['Pokémon_Caught_ROC'] = df3['Pokémon_Caught'].pct_change() * 100
df3['Pokémon_Stops_ROC'] = df3['Pokémon_Stops'].pct_change() * 100
df3

# 43% further walked;
# 97% more Pokémons caught;
# 78% more Pokémon stops spun;
#  since previous entry in logbook.
# Out:
#         Nickname  Level Character_Created          Entry_Added  \
# 0  Populus145085     38        2016-07-08  2022-12-29 00:00:00
# 1  Populus145085     41        2016-07-08  2023-10-05 13:46:59
#
#    Distance_Walked  Pokémon_Caught  Pokémon_Stops  ID  Distance_Walked_ROC  \
# 0             1306            9933           4385   1                  NaN
# 1             1869           19597           7821   2            43.108729
#
#    Pokémon_Caught_ROC  Pokémon_Stops_ROC
# 0                 NaN                NaN
# 1           97.291855          78.358039

# %%
df4 = pd.read_csv('world_of_warcraft.csv') # What class do I have the most characters of?

df4['Class'].count() # 31 Characters with a class.
df4['Class'].nunique() # 11 Unique classes played.
df4['Class'].value_counts() # 5 Warriors, 5 Warlocks and 5 Priests.
# Out:
# Class
# Warrior         5
# Warlock         5
# Priest          5
# Hunter          3
# Shaman          3
# Rogue           2
# Mage            2
# Death Knight    2
# Paladin         2
# Druid           1
# Demon Hunter    1
# Name: count, dtype: int64

# %%
# That's the little interesting data I have from my personal vaults. I wish I knew where to find interesting datasets for free.

# %%
# Updating the database(s) with new logbook entries at the end of this year, 2024.
