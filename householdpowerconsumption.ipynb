# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('household_power_consumption.csv') # I just want to know when there is the most electricity used.

# %%
sns.lineplot(data = df, x = 'Time', y = 'Global_intensity') # Compute-heavy, many rows.
# Out:
# F:\Software\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Software\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Time', ylabel='Global_intensity'>

# %%
# Note: If I knew how, I would downsize the interval from each minute to each hour to save CPU. 
# Secondly I would use plt.tight_layout() if it worked the way I thought it worked. Right now the 'Time' axis is overlapping itself and furthermore is showing 02-25 for some reason.
